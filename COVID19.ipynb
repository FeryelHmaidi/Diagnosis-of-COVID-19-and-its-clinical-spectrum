# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_row', 111)

# %%
data=pd.read_excel('C:/Users/user/Desktop/machine learning/ML3/dataset.xlsx')

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
df1=data.copy()

# %%
df1.shape
# Out:
# (5644, 111)

# %%
df1.dtypes
# Out:
# Patient ID                                                object
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                    object
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
# Patient addmited to intensive care unit (1=yes, 0=no)      int64
# Hematocrit                                               float64
# Hemoglobin                                               float64
# Platelets                                                float64
# Mean platelet volume                                     float64
# Red blood Cells                                          float64
# Lymphocytes                                              float64
# Mean corpuscular hemoglobin concentration (MCHC)         float64
# Leukocytes                                               float64
# ...

# %%
df1.dtypes.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df1.isna()
# Out:
#       Patient ID  Patient age quantile  SARS-Cov-2 exam result  \
# 0          False                 False                   False
# 1          False                 False                   False
# 2          False                 False                   False
# 3          False                 False                   False
# 4          False                 False                   False
# ...          ...                   ...                     ...
# 5639       False                 False                   False
# 5640       False                 False                   False
# 5641       False                 False                   False
# 5642       False                 False                   False
# 5643       False                 False                   False
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                              False
# 1                                              False
# ...

# %%
(df1.isna().sum()/df1.shape[0]).sort_values(ascending=True)
# Out:
# Patient ID                                               0.000000
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
# Influenza B                                              0.760099
# Influenza A                                              0.760099
# Respiratory Syncytial Virus                              0.760099
# Parainfluenza 1                                          0.760454
# Rhinovirus/Enterovirus                                   0.760454
# Coronavirus HKU1                                         0.760454
# Chlamydophila pneumoniae                                 0.760454
# CoronavirusNL63                                          0.760454
# ...

# %%
sns.heatmap(df1.isna(),cbar=False)
# Out:
# <Axes: >

# %%
df1=df1[df1.columns[df1.isna().sum()/df1.shape[0]<0.9]]

# %%
df1.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
df1=df1.drop('Patient ID',axis=1)

# %%
df1
# Out:
#       Patient age quantile SARS-Cov-2 exam result  \
# 0                       13               negative
# 1                       17               negative
# 2                        8               negative
# 3                        5               negative
# 4                       15               negative
# ...                    ...                    ...
# 5639                     3               positive
# 5640                    17               negative
# 5641                     4               negative
# 5642                    10               negative
# 5643                    19               positive
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...

# %%
df1['SARS-Cov-2 exam result'].value_counts(normalize=True)
# Out:
# SARS-Cov-2 exam result
# negative    0.901134
# positive    0.098866
# Name: proportion, dtype: float64

# %%
df1['SARS-Cov-2 exam result'].unique()
# Out:
# array(['negative', 'positive'], dtype=object)

# %%
positive_df=df1[df1['SARS-Cov-2 exam result']=='positive']
negative_df=df1[df1['SARS-Cov-2 exam result']=='negative']

# %%
missing_rate=df1.isna().sum()/df1.shape[0]

# %%
pd.crosstab(df1['SARS-Cov-2 exam result'], df1['Influenza A'])
# Out:
# Influenza A             detected  not_detected
# SARS-Cov-2 exam result
# negative                      18          1224
# positive                       0           112

# %%
df1.dropna().count()
# Out:
# Patient age quantile                                     99
# SARS-Cov-2 exam result                                   99
# Patient addmited to regular ward (1=yes, 0=no)           99
# Patient addmited to semi-intensive unit (1=yes, 0=no)    99
# Patient addmited to intensive care unit (1=yes, 0=no)    99
# Hematocrit                                               99
# Hemoglobin                                               99
# Platelets                                                99
# Mean platelet volume                                     99
# Red blood Cells                                          99
# Lymphocytes                                              99
# Mean corpuscular hemoglobin concentration (MCHC)         99
# Leukocytes                                               99
# Basophils                                                99
# Mean corpuscular hemoglobin (MCH)                        99
# Eosinophils                                              99
# ...

# %%
missing_rate
# Out:
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
# Hematocrit                                               0.893161
# Hemoglobin                                               0.893161
# Platelets                                                0.893338
# Mean platelet volume                                     0.893870
# Red blood Cells                                          0.893338
# Lymphocytes                                              0.893338
# Mean corpuscular hemoglobin concentration (MCHC)         0.893338
# Leukocytes                                               0.893338
# Basophils                                                0.893338
# ...

# %%
blood_columns=list(df1.columns[(missing_rate < 0.9) & (missing_rate > 0.88)])
viral_columns=list(df1.columns[(missing_rate < 0.80) & (missing_rate > 0.75)])

# %%
key_columns= ['Patient age quantile',  'SARS-Cov-2 exam result']

# %%
df1= df1[ key_columns + blood_columns + viral_columns]

# %%
df1.head()
# Out:
#    Patient age quantile SARS-Cov-2 exam result  Hematocrit  Hemoglobin  \
# 0                    13               negative         NaN         NaN
# 1                    17               negative    0.236515    -0.02234
# 2                     8               negative         NaN         NaN
# 3                     5               negative         NaN         NaN
# 4                    15               negative         NaN         NaN
#
#    Platelets  Mean platelet volume   Red blood Cells  Lymphocytes  \
# 0        NaN                    NaN              NaN          NaN
# 1  -0.517413               0.010677         0.102004     0.318366
# 2        NaN                    NaN              NaN          NaN
# 3        NaN                    NaN              NaN          NaN
# 4        NaN                    NaN              NaN          NaN
#
#    Mean corpuscular hemoglobin concentration (MCHC)  Leukocytes  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
trainset , testset = train_test_split(df1,test_size=0.2,random_state=0)

# %%
testset
# Out:
#       Patient age quantile SARS-Cov-2 exam result  Hematocrit  Hemoglobin  \
# 5113                     7               negative         NaN         NaN
# 2343                     7               negative         NaN         NaN
# 2552                     1               negative         NaN         NaN
# 895                     11               negative   -0.152590    0.416252
# 4762                     4               negative    0.442512    0.353596
# ...                    ...                    ...         ...         ...
# 1002                     1               negative         NaN         NaN
# 2701                     4               negative         NaN         NaN
# 2266                     2               negative         NaN         NaN
# 3380                    13               negative         NaN         NaN
# 3592                    19               negative         NaN         NaN
#
#       Platelets  Mean platelet volume   Red blood Cells  Lymphocytes  \
# ...

# %%
testset
# Out:
#       Patient age quantile SARS-Cov-2 exam result  Hematocrit  Hemoglobin  \
# 5113                     7               negative         NaN         NaN
# 2343                     7               negative         NaN         NaN
# 2552                     1               negative         NaN         NaN
# 895                     11               negative   -0.152590    0.416252
# 4762                     4               negative    0.442512    0.353596
# ...                    ...                    ...         ...         ...
# 1002                     1               negative         NaN         NaN
# 2701                     4               negative         NaN         NaN
# 2266                     2               negative         NaN         NaN
# 3380                    13               negative         NaN         NaN
# 3592                    19               negative         NaN         NaN
#
#       Platelets  Mean platelet volume   Red blood Cells  Lymphocytes  \
# ...

# %%
trainset['SARS-Cov-2 exam result']
# Out:
# 543     negative
# 4937    negative
# 2884    negative
# 1837    negative
# 2228    negative
#           ...
# 4931    negative
# 3264    negative
# 1653    negative
# 2607    negative
# 2732    negative
# Name: SARS-Cov-2 exam result, Length: 4515, dtype: object

# %%
testset['SARS-Cov-2 exam result']
# Out:
# 5113    negative
# 2343    negative
# 2552    negative
# 895     negative
# 4762    negative
#           ...
# 1002    negative
# 2701    negative
# 2266    negative
# 3380    negative
# 3592    negative
# Name: SARS-Cov-2 exam result, Length: 1129, dtype: object

# %%
for col in df1.select_dtypes('object'):
    print (f'{col :-<50} {df1[col].unique()}')
# Out:
# SARS-Cov-2 exam result---------------------------- ['negative' 'positive']
# Respiratory Syncytial Virus----------------------- [nan 'not_detected' 'detected']
# Influenza A--------------------------------------- [nan 'not_detected' 'detected']
# Influenza B--------------------------------------- [nan 'not_detected' 'detected']
# Parainfluenza 1----------------------------------- [nan 'not_detected' 'detected']
# CoronavirusNL63----------------------------------- [nan 'not_detected' 'detected']
# Rhinovirus/Enterovirus---------------------------- [nan 'detected' 'not_detected']
# Coronavirus HKU1---------------------------------- [nan 'not_detected' 'detected']
# Parainfluenza 3----------------------------------- [nan 'not_detected' 'detected']
# Chlamydophila pneumoniae-------------------------- [nan 'not_detected' 'detected']
# Adenovirus---------------------------------------- [nan 'not_detected' 'detected']
# ...

# %%
code={'positive':1,
      'negative':0,
      'detected':1,
      'not_detected':0}

# %%
for col in df1.select_dtypes('object'):
    df1[col]=df1[col].map(code )

# %%
df1
# Out:
#       Patient age quantile  SARS-Cov-2 exam result  Hematocrit  Hemoglobin  \
# 0                       13                       0         NaN         NaN
# 1                       17                       0    0.236515   -0.022340
# 2                        8                       0         NaN         NaN
# 3                        5                       0         NaN         NaN
# 4                       15                       0         NaN         NaN
# ...                    ...                     ...         ...         ...
# 5639                     3                       1         NaN         NaN
# 5640                    17                       0         NaN         NaN
# 5641                     4                       0         NaN         NaN
# 5642                    10                       0         NaN         NaN
# 5643                    19                       1    0.694287    0.541564
#
# ...

# %%
df1.dtypes.value_counts()
# Out:
# float64    31
# int64       2
# Name: count, dtype: int64

# %%
def encodage(df1):
      
    code={'positive':1,
          
          'negative':0,
          'detected':1,
          'not_detected':0}
    for col in df1.select_dtypes('object'):
          df1[col]=df1[col].map(code )
    return df1
def feature_engineering(df1):
      df1['est malade']=df[viral_columns].sum(axis=1)>=1
      df1=df1.drop(viral_columns, axis=1)
      return df1

# %%
def imputation(df1):
    df1= df1.dropna(axis=0)
    return df1

# %%
def preprocessing(df1):
    df1=encodage(df1)
    feature_engineering(df1)
    df1=imputation(df1)
    X=df1.drop('SARS-Cov-2 exam result',axis=1)
    y=df1['SARS-Cov-2 exam result']
    return X,y

# %%
X_train , y_train =preprocessing(trainset)

# %%
X_test , y_test=preprocessing(testset)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif

# %%
model= make_pipeline(SelectKBest(f_classif,k=10), RandomForestClassifier(random_state=0))

# %%
#Procedure d'evaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve

# %%
def evaluation(model):
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print(confusion_matrix(y_test,y_pred))
    print(classification_report(y_test,y_pred))
    N, train_score, val_score= learning_curve(model, X_train , y_train,cv=4 , scoring='f1', train_sizes=np.linspace(0.1,1 , 10))
    plt.figure(figsize=(12,8))
    plt.plot(N,train_score.mean(axis=1),label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %%
evaluation(model)

# %%
pd.DataFrame(model.feature_importances_, index=X_train.columns).plot.bar()
# Out:
# <Axes: >
